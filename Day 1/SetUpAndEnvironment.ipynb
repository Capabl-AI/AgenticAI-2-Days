# %% [markdown]
# # 🔧 Session 1: Setup & Environment
#
# **Objective:**
# Prepare the Colab environment for AI Agent development using LangChain, FAISS, PyPDF, and Gemini API (via Google Colab secrets).
#
# **Why This Matters:**
# - Everyone works in the same Colab environment.
# - **Colab Secrets Manager** keeps API keys secure without uploading `.env` files.
# - Ensures a smooth start before we dive into Retrieval-Augmented Generation (RAG).

# %% [markdown]
# ## ✅ Step 1: Install Required Libraries
# We’ll install:
# - **LangChain** → Framework for building LLM-powered apps
# - **FAISS** → Vector store for embeddings
# - **PyPDF** → Load PDF files
# - **python-dotenv** → Optional (not required if we use Colab secrets)
# - **Google Generative AI SDK** → Access Gemini

# %%
# !pip install -q langchain==1.0.5 faiss-cpu==1.12.0 pypdf==6.2.0 python-dotenv==1.2.1 langchain-google-genai==3.0.1
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.6/326.6 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.2/471.2 kB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.3/208.3 kB 16.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.9.0 which is incompatible.

# %%
# !pip show langchain faiss-cpu pypdf python-dotenv langchain-google-genai langchain-core
# Out:
# Name: langchain
# Version: 1.0.5
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# ---
# Name: faiss-cpu
# Version: 1.12.0
# Summary: A library for efficient similarity search and clustering of dense vectors.
# Home-page:
# Author:
# Author-email: Kota Yamaguchi <yamaguchi_kota@cyberagent.co.jp>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: numpy, packaging
# Required-by:
# ---
# Name: pypdf
# Version: 6.2.0
# Summary: A pure-python PDF library capable of splitting, merging, cropping, and transforming PDF files
# Home-page:
# Author:
# Author-email: Mathieu Fenniak <biziqe@mathieu.fenniak.net>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires:
# Required-by:
# ---
# Name: python-dotenv
# Version: 1.2.1
# Summary: Read key-value pairs from a .env file and set them as environment variables
# Home-page:
# Author:
# Author-email: Saurabh Kumar <me+github@saurabh-kumar.com>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires:
# Required-by: google-adk, pydantic-settings
# ---
# Name: langchain-google-genai
# Version: 3.0.1
# Summary: An integration package connecting Google's genai package and LangChain
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: filetype, google-ai-generativelanguage, langchain-core, pydantic
# Required-by:
# ---
# Name: langchain-core
# Version: 1.0.4
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: jsonpatch, langsmith, packaging, pydantic, pyyaml, tenacity, typing-extensions
# Required-by: langchain, langchain-google-genai, langchain-text-splitters, langgraph, langgraph-checkpoint, langgraph-prebuilt

# %% [markdown]
# ## ✅ Step 2: Setup Gemini API Key using Colab Secrets
#
# - In Colab:
#   ` Secrets → Add new secret`
# - Add a secret with key = **GEMINI_API_KEY**
# - Then, we’ll fetch it in the notebook:

# %%
from google.colab import userdata

# Load Gemini API key from Colab secrets
GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')

if GEMINI_API_KEY:
    print("✅ Gemini API key retrieved from Colab Secrets!")
else:
    print("❌ Gemini API key not found. Please add it in Colab Secrets.")
# Out:
# ✅ Gemini API key retrieved from Colab Secrets!

# %% [markdown]
# ## ✅ Step 3: Verify Installation with Gemini Test Call
# We’ll run a simple Gemini call via LangChain to check setup.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize Gemini model
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", google_api_key=GEMINI_API_KEY)

# Test prompt
response = llm.invoke("Hello Gemini! Why is LangChain important in AI agent development?")
print("Gemini Response:", response.content)
# Out:
# Gemini Response: LangChain has emerged as a critically important framework in AI agent development because it provides the **structured components, abstractions, and orchestration capabilities** necessary to transform a powerful but stateless Large Language Model (LLM) into a dynamic, stateful, and interactive AI agent.
#
# Here's a breakdown of why it's so important:
#
# 1.  **Orchestration and Chaining:**
#     *   **Problem:** AI agents often require multi-step reasoning, decision-making, and interaction. A single LLM call isn't enough.
#     *   **LangChain's Solution:** It allows you to chain together multiple LLM calls, tools, and processing steps in a defined sequence or based on an agent's reasoning. This is fundamental for complex tasks that involve planning, execution, and observation.
#
# 2.  **Tool Integration (Empowering the LLM to Act):**
#     *   **Problem:** LLMs are great at text generation but cannot directly interact with the outside world (e.g., search the internet, query a database, run code, send an email).
#     *   **LangChain's Solution:** It provides a standardized way to define and integrate "Tools" that an LLM can use. These tools are essentially functions that the LLM can call based on its reasoning. This transforms an LLM from a passive text generator into an active entity that can perform actions in the real or digital world.
#
# 3.  **Memory Management (Statefulness):**
#     *   **Problem:** LLMs are stateless by default. Each interaction is treated as new, without remembering past conversations or actions. Agents, however, need to maintain context over time.
#     *   **LangChain's Solution:** It offers various memory modules (e.g., conversational buffer memory, entity memory) that allow agents to remember previous turns, specific facts, or user preferences, making interactions more coherent and personalized.
#
# 4.  **Data Augmentation and Retrieval (Knowledge Base):**
#     *   **Problem:** LLMs have a cutoff date for their training data and don't have access to real-time information or private company data.
#     *   **LangChain's Solution:** It facilitates Retrieval Augmented Generation (RAG) by providing components for loading, splitting, embedding, and retrieving documents from external knowledge bases (e.g., PDFs, databases, websites). This allows agents to access up-to-date and specific information, greatly expanding their utility and accuracy.
#
# 5.  **Agentic Loops and Reasoning:**
#     *   **Problem:** Building an autonomous agent requires an iterative loop of thought, action, observation, and refinement.
#     *   **LangChain's Solution:** It provides the "Agent" abstraction, which often involves a "ReAct" (Reasoning and Acting) pattern. The LLM acts as the "brain," deciding what to do next, using tools, observing the results, and then refining its plan. LangChain helps define and manage this iterative process.
#
# 6.  **Modularity and Abstraction:**
#     *   **Problem:** Building complex AI applications from scratch is difficult and time-consuming.
#     *   **LangChain's Solution:** It breaks down the components of an AI agent (LLMs, prompts, tools, memory, chains) into modular, reusable pieces. This simplifies development, promotes best practices, and allows developers to swap out different LLM providers, vector stores, or memory types with minimal code changes.
#
# 7.  **Prompt Management:**
#     *   **Problem:** Crafting effective prompts for complex agent behavior can be challenging and requires dynamic insertion of context, tools, and instructions.
#     *   **LangChain's Solution:** It offers `PromptTemplates` that allow for dynamic and structured prompt creation, making it easier to manage and optimize the instructions given to the LLM for various agent tasks.
#
# In essence, LangChain acts as an **operating system for AI agents**, providing the necessary infrastructure for LLMs to move beyond simple text generation and become intelligent, interactive, and capable entities that can understand, reason, plan, act, and remember within complex environments.
